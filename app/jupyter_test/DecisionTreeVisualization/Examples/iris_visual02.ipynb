# %%
import pandas as pd
from sklearn.datasets import load_iris
import os  
os.chdir('D:/zxdf/Workspaces/PycharmProjects/flask_ml')
# %matplotlib inline
data = load_iris()

# %%
#data.data
#data.target
#print zip(data.data,data.target)

# %%
#data.data
pos=pd.DataFrame(data.data)
#pos=data.data
pos.insert(4,'name',data.target)
#pos['col4'] = data.target[:]
#pos['col5'] = pd.DataFrame(data.target,array(150,1))
#pos[149]='ColumnD'
#pos['Name'] = data.target

# %%
pos
# Out:
#        0    1    2    3  name
# 0    5.1  3.5  1.4  0.2     0
# 1    4.9  3.0  1.4  0.2     0
# 2    4.7  3.2  1.3  0.2     0
# 3    4.6  3.1  1.5  0.2     0
# 4    5.0  3.6  1.4  0.2     0
# 5    5.4  3.9  1.7  0.4     0
# 6    4.6  3.4  1.4  0.3     0
# 7    5.0  3.4  1.5  0.2     0
# 8    4.4  2.9  1.4  0.2     0
# 9    4.9  3.1  1.5  0.1     0
# 10   5.4  3.7  1.5  0.2     0
# 11   4.8  3.4  1.6  0.2     0
# 12   4.8  3.0  1.4  0.1     0
# 13   4.3  3.0  1.1  0.1     0
# 14   5.8  4.0  1.2  0.2     0
# 15   5.7  4.4  1.5  0.4     0
# 16   5.4  3.9  1.3  0.4     0
# 17   5.1  3.5  1.4  0.3     0
# 18   5.7  3.8  1.7  0.3     0
# 19   5.1  3.8  1.5  0.3     0
# 20   5.4  3.4  1.7  0.2     0
# 21   5.1  3.7  1.5  0.4     0
# 22   4.6  3.6  1.0  0.2     0
# 23   5.1  3.3  1.7  0.5     0
# 24   4.8  3.4  1.9  0.2     0
# 25   5.0  3.0  1.6  0.2     0
# 26   5.0  3.4  1.6  0.4     0
# 27   5.2  3.5  1.5  0.2     0
# 28   5.2  3.4  1.4  0.2     0
# 29   4.7  3.2  1.6  0.2     0
# ...

# %%
import matplotlib.pyplot as plt
from pandas.tools.plotting import andrews_curves
plt.figure()

andrews_curves(pos, 'name')
# Out:
# D:\zxdf\software\Anaconda2\envs\flask_ml\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: 'pandas.tools.plotting.andrews_curves' is deprecated, import 'pandas.plotting.andrews_curves' instead.
#   """
