# %%
# -*- coding: utf-8 -*-
import sys
import os       
import pandas as pd
import datetime
os.chdir('D:/zxdf/Workspaces/PycharmProjects/flask_ml')
from app import config, Elasticsearch_Util

starttime = datetime.datetime.now()
print ("当前的日期和时间是 %s" % starttime)

# %%
result="""from::to::score;;(u'MySQLSyntaxErrorException',)::(u'Aborting',)::0.4;;(u'Aborting',)::(u'MySQLSyntaxErrorException',)::0.5;;(u'Aborting',)::(u'Failed to find tablespace',)::0.75;;(u'java.io.EOFException',)::(u'org.quartz.JobPersistenceException',)::1.0;;(u'org.quartz.JobPersistenceException',)::(u'java.io.EOFException',)::1.0;;(u'java.io.EOFException',)::(u'java.net.ConnectException',)::1.0;;(u'java.net.ConnectException',)::(u'java.io.EOFException',)::1.0;;(u'java.net.ConnectException',)::(u'org.quartz.JobPersistenceException',)::1.0;;(u'org.quartz.JobPersistenceException',)::(u'java.net.ConnectException',)::1.0;;(u'Failed to find tablespace',)::(u'Aborting',)::1.0;;(u'java.net.ConnectException',)::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'java.net.ConnectException',)::1.0;;(u'org.quartz.JobPersistenceException',)::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'org.quartz.JobPersistenceException',)::1.0;;(u'CommunicationsException',)::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'CommunicationsException',)::1.0;;(u'java.io.EOFException',)::(u'CommunicationsException',)::1.0;;(u'CommunicationsException',)::(u'java.io.EOFException',)::1.0;;(u'java.net.ConnectException',)::(u'CommunicationsException',)::1.0;;(u'CommunicationsException',)::(u'java.net.ConnectException',)::1.0;;(u'java.io.EOFException',)::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'java.io.EOFException',)::1.0;;(u'MysqlStopUNExpect',)::(u'SQLNonTransientConnectionException',)::1.0;;(u'SQLNonTransientConnectionException',)::(u'MysqlStopUNExpect',)::1.0;;(u'org.quartz.JobPersistenceException',)::(u'CommunicationsException',)::1.0;;(u'CommunicationsException',)::(u'org.quartz.JobPersistenceException',)::1.0;;(u'java.io.EOFException',)::(u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'org.quartz.JobPersistenceException',)::(u'java.io.EOFException', u'CommunicationsException')::1.0;;(u'CommunicationsException',)::(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::(u'CommunicationsException',)::1.0;;(u'java.io.EOFException', u'CommunicationsException')::(u'org.quartz.JobPersistenceException',)::1.0;;(u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'java.io.EOFException',)::1.0;;(u'java.io.EOFException',)::(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.net.ConnectException',)::(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'java.io.EOFException', u'java.net.ConnectException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException')::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException',)::1.0;;(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException',)::1.0;;(u'java.net.ConnectException',)::(u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'org.quartz.JobPersistenceException',)::(u'java.net.ConnectException', u'CommunicationsException')::1.0;;(u'CommunicationsException',)::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::(u'CommunicationsException',)::1.0;;(u'java.net.ConnectException', u'CommunicationsException')::(u'org.quartz.JobPersistenceException',)::1.0;;(u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'java.net.ConnectException',)::1.0;;(u'java.io.EOFException',)::(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'org.quartz.JobPersistenceException',)::(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'org.quartz.JobPersistenceException',)::1.0;;(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException',)::1.0;;(u'java.io.EOFException',)::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::1.0;;(u'java.net.ConnectException',)::(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::1.0;;(u'org.quartz.JobPersistenceException',)::(u'java.io.EOFException', u'java.net.ConnectException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException')::(u'org.quartz.JobPersistenceException',)::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::(u'java.net.ConnectException',)::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::(u'java.io.EOFException',)::1.0;;(u'java.io.EOFException',)::(u'java.net.ConnectException', u'CommunicationsException')::1.0;;(u'java.net.ConnectException',)::(u'java.io.EOFException', u'CommunicationsException')::1.0;;(u'CommunicationsException',)::(u'java.io.EOFException', u'java.net.ConnectException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException')::(u'CommunicationsException',)::1.0;;(u'java.io.EOFException', u'CommunicationsException')::(u'java.net.ConnectException',)::1.0;;(u'java.net.ConnectException', u'CommunicationsException')::(u'java.io.EOFException',)::1.0;;(u'java.net.ConnectException',)::(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'CommunicationsException',)::(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'java.net.ConnectException', u'CommunicationsException')::1.0;;(u'java.net.ConnectException', u'CommunicationsException')::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'CommunicationsException',)::1.0;;(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException',)::1.0;;(u'java.net.ConnectException',)::(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'org.quartz.JobPersistenceException',)::(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'org.quartz.JobPersistenceException',)::1.0;;(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException',)::1.0;;(u'java.io.EOFException',)::(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'CommunicationsException',)::(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'java.io.EOFException', u'CommunicationsException')::1.0;;(u'java.io.EOFException', u'CommunicationsException')::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'CommunicationsException',)::1.0;;(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException',)::1.0;;(u'org.quartz.JobPersistenceException',)::(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'CommunicationsException',)::(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'CommunicationsException',)::1.0;;(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'org.quartz.JobPersistenceException',)::1.0;;(u'java.io.EOFException',)::(u'java.net.ConnectException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.net.ConnectException',)::(u'java.io.EOFException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'java.io.EOFException', u'java.net.ConnectException', u'CommunicationsException')::1.0;;(u'CommunicationsException',)::(u'java.io.EOFException', u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException')::(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException', u'CommunicationsException')::1.0;;(u'java.io.EOFException', u'CommunicationsException')::(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException', u'CommunicationsException')::1.0;;(u'java.net.ConnectException', u'CommunicationsException')::(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException', u'java.net.ConnectException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'CommunicationsException',)::1.0;;(u'java.io.EOFException', u'java.net.ConnectException', u'CommunicationsException')::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'java.io.EOFException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException',)::1.0;;(u'java.net.ConnectException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException',)::1.0;;(u'java.net.ConnectException',)::(u'org.quartz.JobPersistenceException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'org.quartz.JobPersistenceException',)::(u'java.net.ConnectException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'CommunicationsException',)::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.net.ConnectException', u'CommunicationsException')::(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException', u'CommunicationsException')::1.0;;(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::1.0;;(u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'CommunicationsException',)::1.0;;(u'java.net.ConnectException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'org.quartz.JobPersistenceException',)::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'org.quartz.JobPersistenceException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException',)::1.0;;(u'java.io.EOFException',)::(u'org.quartz.JobPersistenceException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'org.quartz.JobPersistenceException',)::(u'java.io.EOFException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'CommunicationsException',)::(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.io.EOFException', u'CommunicationsException')::(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException', u'CommunicationsException')::1.0;;(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::1.0;;(u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'CommunicationsException',)::1.0;;(u'java.io.EOFException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'org.quartz.JobPersistenceException',)::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'org.quartz.JobPersistenceException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException',)::1.0;;(u'java.io.EOFException',)::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.net.ConnectException',)::(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'java.io.EOFException', u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::1.0;;(u'org.quartz.JobPersistenceException',)::(u'java.io.EOFException', u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException')::(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException', u'java.net.ConnectException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'org.quartz.JobPersistenceException',)::1.0;;(u'java.io.EOFException', u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException',)::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException',)::1.0;;(u'java.io.EOFException',)::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'java.net.ConnectException',)::(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'org.quartz.JobPersistenceException',)::(u'java.io.EOFException', u'java.net.ConnectException', u'CommunicationsException')::1.0;;(u'CommunicationsException',)::(u'java.io.EOFException', u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException')::(u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::(u'java.net.ConnectException', u'CommunicationsException')::1.0;;(u'java.io.EOFException', u'CommunicationsException')::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::(u'java.io.EOFException', u'CommunicationsException')::1.0;;(u'java.net.ConnectException', u'CommunicationsException')::(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::1.0;;(u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'java.io.EOFException', u'java.net.ConnectException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::(u'CommunicationsException',)::1.0;;(u'java.io.EOFException', u'java.net.ConnectException', u'CommunicationsException')::(u'org.quartz.JobPersistenceException',)::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'java.net.ConnectException',)::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'java.io.EOFException',)::1.0;;(u'java.net.ConnectException',)::(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'org.quartz.JobPersistenceException',)::(u'java.io.EOFException', u'java.net.ConnectException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.io.EOFException',)::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::(u'java.io.EOFException', u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'CommunicationsException',)::(u'java.io.EOFException', u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::(u'java.io.EOFException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException')::(u'org.quartz.JobPersistenceException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'java.net.ConnectException', u'CommunicationsException')::(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::(u'java.net.ConnectException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException', u'java.net.ConnectException', u'CommunicationsException')::1.0;;(u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'java.io.EOFException', u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'java.io.EOFException', u'CommunicationsException')::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException', u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::(u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException', u'CommunicationsException')::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'java.io.EOFException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'org.quartz.JobPersistenceException', u'CommunicationsException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException', u'CommunicationsException')::(u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'java.net.ConnectException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException', u'org.quartz.JobPersistenceException')::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException', u'CommunicationsException')::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'java.net.ConnectException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::1.0;;(u'org.quartz.JobPersistenceException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException', u'java.net.ConnectException')::1.0;;(u'java.io.EOFException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException', u'org.quartz.JobPersistenceException')::1.0;;(u'java.io.EOFException', u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'CommunicationsException',)::1.0;;(u'java.io.EOFException', u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'CommunicationsException')::(u'com.alibaba.druid.pool.GetConnectionTimeoutException',)::1.0;;(u'java.net.ConnectException', u'org.quartz.JobPersistenceException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.io.EOFException',)::1.0;;(u'java.io.EOFException', u'java.net.ConnectException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'org.quartz.JobPersistenceException',)::1.0;;(u'java.io.EOFException', u'org.quartz.JobPersistenceException', u'CommunicationsException', u'com.alibaba.druid.pool.GetConnectionTimeoutException')::(u'java.net.ConnectException',)::1.0"""

f = open(r"E:\zxdf\ml\linkdata-log\dataset\testrecord\logbody.txt", "w")
for indexs in train_data.index:
    print >> f, "%s%s%s%s" %(train_data.loc[indexs].values[0:1],train_data.loc[indexs].values[1:2],train_data.loc[indexs].values[2:3],train_data.loc[indexs].values[3:4])
f.close()
